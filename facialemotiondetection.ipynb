# %%
from keras.utils import to_categorical
from keras.preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
TRAIN_DIR = "/kaggle/input/emotion-detection-fer/train"
TEST_DIR = "/kaggle/input/emotion-detection-fer/test"

# %%
def create_dataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir, label)):
            image_paths.append(os.path.join(dir, label, imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths, labels

# %%
train = pd.DataFrame()
train['image'], train['label'] = create_dataframe(TRAIN_DIR)
# Out:
# fearful completed
# disgusted completed
# angry completed
# neutral completed
# sad completed
# surprised completed
# happy completed

# %%
test = pd.DataFrame()
test['image'], test['label'] = create_dataframe(TEST_DIR)
# Out:
# fearful completed
# disgusted completed
# angry completed
# neutral completed
# sad completed
# surprised completed
# happy completed

# %%
def extract_features(images):
    features = []
    for image in images:
        img = load_img(image, color_mode="grayscale")
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features), 48, 48, 1)
    return features

# %%
train_features = extract_features(train['image'])

# %%
test_features = extract_features(test['image'])

# %%
x_train = train_features / 255.0
x_test = test_features / 255.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(train['label'])
y_train = to_categorical(le.transform(train['label']), num_classes=7)
y_test = to_categorical(le.transform(test['label']), num_classes=7)

# %%
from keras.layers import BatchNormalization, Activation

model = Sequential()

# First conv layer
model.add(Conv2D(64, (3, 3), padding='same', input_shape=(48, 48, 1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Second conv layer
model.add(Conv2D(128, (5, 5), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Third conv layer
model.add(Conv2D(512, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Fourth conv layer
model.add(Conv2D(512, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening
model.add(Flatten())

# Fully connected layer 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(7, activation='softmax'))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x=x_train, y=y_train, batch_size=128, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
#   2/225 ━━━━━━━━━━━━━━━━━━━━ 18s 81ms/step - accuracy: 0.1211 - loss: 2.5385
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1713197670.585321      89 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1713197670.611168      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.2174 - loss: 2.0298
# W0000 00:00:1713197698.021220      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1713197699.226723      87 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 59s 138ms/step - accuracy: 0.2176 - loss: 2.0293 - val_accuracy: 0.1785 - val_loss: 2.1557
# Epoch 2/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.3836 - loss: 1.6006 - val_accuracy: 0.3704 - val_loss: 1.6540
# Epoch 3/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 57ms/step - accuracy: 0.4679 - loss: 1.3740 - val_accuracy: 0.4533 - val_loss: 1.4380
# Epoch 4/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - accuracy: 0.5199 - loss: 1.2552 - val_accuracy: 0.5235 - val_loss: 1.2455
# Epoch 5/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - accuracy: 0.5579 - loss: 1.1680 - val_accuracy: 0.3764 - val_loss: 1.6281
# Epoch 6/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - accuracy: 0.5824 - loss: 1.1121 - val_accuracy: 0.5535 - val_loss: 1.1380
# Epoch 7/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 14s 60ms/step - accuracy: 0.6006 - loss: 1.0576 - val_accuracy: 0.5162 - val_loss: 1.2341
# Epoch 8/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 14s 60ms/step - accuracy: 0.6153 - loss: 1.0263 - val_accuracy: 0.5591 - val_loss: 1.1526
# Epoch 9/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 60ms/step - accuracy: 0.6314 - loss: 0.9768 - val_accuracy: 0.5734 - val_loss: 1.1085
# Epoch 10/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - accuracy: 0.6507 - loss: 0.9337 - val_accuracy: 0.5970 - val_loss: 1.0737
# Epoch 11/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - accuracy: 0.6648 - loss: 0.8900 - val_accuracy: 0.4974 - val_loss: 1.3621
# Epoch 12/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 60ms/step - accuracy: 0.6846 - loss: 0.8517 - val_accuracy: 0.5626 - val_loss: 1.2595
# Epoch 13/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 60ms/step - accuracy: 0.6973 - loss: 0.8149 - val_accuracy: 0.6142 - val_loss: 1.0647
# Epoch 14/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 60ms/step - accuracy: 0.7208 - loss: 0.7521 - val_accuracy: 0.5093 - val_loss: 1.3885
# Epoch 15/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 60ms/step - accuracy: 0.7328 - loss: 0.7232 - val_accuracy: 0.5750 - val_loss: 1.1986
# Epoch 16/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - accuracy: 0
# Epoch 80/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9874 - loss: 0.0383 - val_accuracy: 0.9039 - val_loss: 0.3371
# Epoch 81/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.9883 - loss: 0.0355 - val_accuracy: 0.8901 - val_loss: 0.4029
# Epoch 82/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9896 - loss: 0.0330 - val_accuracy: 0.8719 - val_loss: 0.4788
# Epoch 83/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9876 - loss: 0.0338 - val_accuracy: 0.8825 - val_loss: 0.4412
# Epoch 84/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9820 - loss: 0.0488 - val_accuracy: 0.8713 - val_loss: 0.4832
# Epoch 85/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9862 - loss: 0.0405 - val_accuracy: 0.8622 - val_loss: 0.5411
# Epoch 86/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9892 - loss: 0.0308 - val_accuracy: 0.8458 - val_loss: 0.6142
# Epoch 87/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.9826 - loss: 0.0485 - val_accuracy: 0.8820 - val_loss: 0.4520
# Epoch 88/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9914 - loss: 0.0242 - val_accuracy: 0.8943 - val_loss: 0.3993
# Epoch 89/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9903 - loss: 0.0244 - val_accuracy: 0.8865 - val_loss: 0.4366
# Epoch 90/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9908 - loss: 0.0300 - val_accuracy: 0.8852 - val_loss: 0.4327
# Epoch 91/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.9885 - loss: 0.0312 - val_accuracy: 0.8815 - val_loss: 0.4659
# Epoch 92/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9907 - loss: 0.0263 - val_accuracy: 0.8950 - val_loss: 0.4042
# Epoch 93/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9895 - loss: 0.0294 - val_accuracy: 0.8855 - val_loss: 0.4268
# Epoch 94/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9893 - loss: 0.0268 - val_accuracy: 0.8969 - val_loss: 0.3927
# Epoch 95/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.9934 - loss: 0.0198 - val_accuracy: 0.9006 - val_loss: 0.3852
# Epoch 96/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9929 - loss: 0.0200 - val_accuracy: 0.8882 - val_loss: 0.4347
# Epoch 97/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9931 - loss: 0.0168 - val_accuracy: 0.8977 - val_loss: 0.4065
# Epoch 98/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9907 - loss: 0.0288 - val_accuracy: 0.8977 - val_loss: 0.3913
# Epoch 99/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 136ms/step - accuracy: 0.9932 - loss: 0.0196 - val_accuracy: 0.8859 - val_loss: 0.4388
# Epoch 100/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9936 - loss: 0.0219 - val_accuracy: 0.8933 - val_loss: 0.4217

# %%
val_acc = history.history['val_accuracy']
print("Validation accuracy:", val_acc[-1])
# Out:
# Validation accuracy: 0.8932738900184631

# %%
x_test[0]
# Out:
# array([[[0.32941176],
#         [0.31372549],
#         [0.32941176],
#         ...,
#         [0.68235294],
#         [0.66666667],
#         [0.66666667]],
#
#        [[0.33333333],
#         [0.31764706],
#         [0.32941176],
#         ...,
#         [0.6745098 ],
#         [0.64705882],
#         [0.65490196]],
#
#        [[0.3254902 ],
#         [0.32156863],
#         [0.34901961],
#         ...,
#         [0.67843137],
#         [0.65098039],
#         [0.66666667]],
#
#        ...,
#
#        [[0.11372549],
#         [0.12156863],
#         [0.16862745],
#         ...,
#         [0.71764706],
#         [0.82352941],
#         [0.85490196]],
#
#        [[0.10980392],
#         [0.11764706],
#         [0.1372549 ],
#         ...,
#         [0.7372549 ],
#         [0.81568627],
#         [0.84705882]],
#
#        [[0.08627451],
#         [0.10196078],
#         [0.12941176],
#         ...,
#         [0.75294118],
#         [0.81568627],
#         [0.84313725]]])

# %%
probs = model.predict(x_test)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step

# %%
predicted_labels = np.argmax(probs, axis=1)

# %%
max_probs = np.max(probs, axis=1)

# %%
predicted_emotions = le.inverse_transform(predicted_labels)

# %%
top_predicted_index = np.argmax(max_probs)
top_predicted_emotion = predicted_emotions[top_predicted_index]
top_confidence_score = max_probs[top_predicted_index]

# %%
print("Top predicted emotion:", top_predicted_emotion)
print("Confidence score:", top_confidence_score)
# Out:
# Top predicted emotion: fearful
# Confidence score: 1.0

# %%
model_json = model.to_json()
with open("emotionfacedetect.json", 'w') as json_file:
    json_file.write(model_json)
model.save_weights("emotionfacedetect.weights.h5")

# %%
model_json
# Out:
# '{"module": "keras", "class_name": "Sequential", "config": {"name": "sequential", "trainable": true, "dtype": "float32", "layers": [{"module": "keras.layers", "class_name": "InputLayer", "config": {"batch_shape": [null, 48, 48, 1], "dtype": "float32", "sparse": false, "name": "input_layer"}, "registered_name": null}, {"module": "keras.layers", "class_name": "Conv2D", "config": {"name": "conv2d", "trainable": true, "dtype": "float32", "filters": 64, "kernel_size": [3, 3], "strides": [1, 1], "padding": "same", "data_format": "channels_last", "dilation_rate": [1, 1], "groups": 1, "activation": "linear", "use_bias": true, "kernel_initializer": {"module": "keras.initializers", "class_name": "GlorotUniform", "config": {"seed": null}, "registered_name": null}, "bias_initializer": {"module": "keras.initializers", "class_name": "Zeros", "config": {}, "registered_name": null}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}, "registered_name": null, "build_config": {"input_shape": [null, 48, 48, 1]}}, {"module": "keras.layers", "class_name": "BatchNormalization", "config": {"name": "batch_normalization", "trainable": true, "dtype": "float32", "axis": -1, "momentum": 0.99, "epsilon": 0.001, "center": true, "scale": true, "beta_initializer": {"module": "keras.initializers", "class_name": "Zeros", "config": {}, "registered_name": null}, "gamma_initializer": {"module": "keras.initializers", "class_name": "Ones", "config": {}, "registered_name": null}, "moving_mean_initializer": {"module": "keras.initializers", "class_name": "Zeros", "config": {}, "registered_name": null}, "moving_variance_initializer": {"module": "keras.initializers", "class_name": "Ones", "config": {}, "registered_name": null}, "beta_regularizer": null, "gamma_regularizer": null, "beta_constraint": null, "gamma_constraint": null, "synchronized": false}, "registered_name": null, "build_config": {"input_shape": [null, 48, 48, 64]}}, {"module": "keras.layers", "class_name": "Activation", "config": {"name": "activation", "trainable": true, "dtype": "float32", "activation": "relu"}, "registered_name": null, "build_config": {"input_shape": [null, 48, 48, 64]}}, {"module": "keras.layers", "class_name": "MaxPooling2D", "config": {"name": "max_pooling2d", "trainable": true, "dtype": "float32", "pool_size": [2, 2], "padding": "valid", "strides": [2, 2], "data_format": "channels_last"}, "registered_name": null, "build_config": {"input_shape": [null, 48, 48, 64]}}, {"module": "keras.layers", "class_name": "Dropout", "config": {"name": "dropout", "trainable": true, "dtype": "float32", "rate": 0.25, "seed": null, "noise_shape": null}, "registered_name": null}, {"module": "keras.layers", "class_name": "Conv2D", "config": {"name": "conv2d_1", "trainable": true, "dtype": "float32", "filters": 128, "kernel_size": [5, 5], "strides": [1, 1], "padding": "same", "data_format": "channels_last", "dilation_rate": [1, 1], "groups": 1, "activation": "linear", "use_bias": true, "kernel_initializer": {"module": "keras.initializers", "class_name": "GlorotUniform", "config": {"seed": null}, "registered_name": null}, "bias_initializer": {"module": "keras.initializers", "class_name": "Zeros", "config": {}, "registered_name": null}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}, "registered_name": null, "build_config": {"input_shape": [null, 24, 24, 64]}}, {"module": "keras.layers", "class_name": "BatchNormalization", "config": {"name": "batch_normalization_1", "trainable": true, "dtype": "float32", "axis": -1, "momentum": 0.99, "epsilon": 0.001, "center": true, "scale": true, "beta_initializer": {"module": "keras.initializers", "class_name": "Zeros", "config": {}, "registered_name": null}, "gamma_initializer": {"module": "keras.initializers", "class_name": "Ones", "config": {}, "registered_name": null}, "moving_mean_initializer":  ...

# %%
import joblib
joblib.dump(model_json, 'emotionfacedetect.pkl')
# Out:
# ['emotionfacedetect.pkl']
